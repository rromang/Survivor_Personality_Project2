# %%
import json 
import pandas as pd 
from pandas.io.json import json_normalize #package for flattening json in pandas df

# from https://www.kaggle.com/jboysen/quick-tutorial-flatten-nested-json-in-pandas
#load json object
with open("/Users/rosaicelaroman/Desktop/Data_BootCamp/Survivor_Personality_Project2/templates/castaways.json") as f:
    d = json.load(f)

# %%
df = pd.json_normalize(d["castaways"])
df
# Out:
#            Lat         Lon  age     age_group castaway            city  \
# 0    40.827045  -73.975694   33         26-35  Natalie       Edgewater
# 1    30.421309  -87.216915   40         36-45    Amber       Pensacola
# 2    39.027368  -95.762754   43         36-45    Danni         Shawnee
# 3    43.147079  -71.945743   45         36-45    Ethan    Hillsborough
# 4    33.415112 -111.831479   39         36-45    Tyson            Mesa
# ..         ...         ...  ...           ...      ...             ...
# 739  40.750241  -73.611875   30         26-35     Sean     Carle Place
# 740  42.877788  -88.586212   38         36-45    Susan         Palmyra
# 741  36.852984  -75.977418   72  66 and older     Rudy  Virginia Beach
# 742  35.733073 -118.433946   22         16-25    Kelly       Kernville
# 743  41.489983  -71.313771   39         36-45  Richard         Newport
#
#              full_name   id  immunity_idols_won personality_name  \
# 0     Natalie Anderson    1                   1     Entrepreneur
# 1        Amber Mariano    2                   0       Adventurer
# 2     Danni Boatwright    3                   0      Protagonist
# 3           Ethan Zohn    4                   0       Adventurer
# 4        Tyson Apostol    5                   0     Entrepreneur
# ..                 ...  ...                 ...              ...
# 739       Sean Kenniff  740                   0         Logician
# 740         Susan Hawk  741                   0     Entrepreneur
# 741        Rudy Boesch  742                   1      Logistician
# 742  Kelly Wiglesworth  743                   4       Adventurer
# 743      Richard Hatch  744                   1          Debater
#
#     personality_type          result  season               season_name  \
# 0               ESTP   1st voted out      40  Survivor: Winners at War
# 1               ISFP   2nd voted out      40  Survivor: Winners at War
# 2               ENFJ   3rd voted out      40  Survivor: Winners at War
# 3               ISFP   4th voted out      40  Survivor: Winners at War
# 4               ESTP   5th voted out      40  Survivor: Winners at War
# ..               ...             ...     ...                       ...
# 739             INTP  12th voted out       1          Survivor: Borneo
# 740             ESTP  13th voted out       1          Survivor: Borneo
# 741             ISTJ  14th voted out       1          Survivor: Borneo
# 742             ISFP       Runner-up       1          Survivor: Borneo
# 743             ENTP   Sole Survivor       1          Survivor: Borneo
#
#              state  total_votes_received
# 0       New Jersey                    11
# 1          Florida                     6
# 2           Kansas                     8
# 3    New Hampshire                     4
# 4          Arizona                    12
# ..             ...                   ...
# 739       New York                     9
# 740      Wisconsin                     7
# 741       Virginia                     8
# 742     California                     0
# 743   Rhode Island                     6
#
# [744 rows x 16 columns]

# %%
import plotly.express as px

fig = px.scatter_mapbox(df, lat="Lat", lon="Lon", hover_name="full_name", hover_data=["city", "state", 'personality_name', "result"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-249db0538154> in <module>
#       5 fig.update_layout(mapbox_style="open-street-map")
#       6 fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# ----> 7 fig.show()
#
# ~/opt/anaconda3/envs/survivor_proj_env/lib/python3.7/site-packages/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    3396         import plotly.io as pio
#    3397
# -> 3398         return pio.show(self, *args, **kwargs)
#    3399
#    3400     def to_json(self, *args, **kwargs):
#
# ~/opt/anaconda3/envs/survivor_proj_env/lib/python3.7/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     396         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
#     397             raise ValueError(
# --> 398                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     399             )
#     400
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
